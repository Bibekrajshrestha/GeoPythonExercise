# %%
station_names=['lighthouse','Harmaja','Suomenlinna aaltopoiju', 'Kumpula', 'Kaisaniemi']

# %%
print(station_names)
# Out:
# ['lighthouse', 'Harmaja', 'Suomenlinna aaltopoiju', 'Kumpula', 'Kaisaniemi']

# %%
station_names[0]
# Out:
# 'Harmaja'

# %%
station_start_years=[2003, 1989, 2016, 2005, 1844]

# %%
station_start_years[0]
# Out:
# 1844

# %%
len(station_names)
# Out:
# 8

# %%
len(station_start_years)
# Out:
# 8

# %%
station_names.append('Malmi airfield')

# %%
station_names.append('Vuossari harbour')

# %%
station_names.append('Kaivopuisto')

# %%
station_start_years.append(1937)

# %%
station_start_years.append(2012)

# %%
station_start_years.append(1904)

# %%
station_names.sort()

# %%
station_start_years.sort()

# %%
#problem 2
selected_month_index = input('enter the month index, 0 to 11 = ')
# Out:
# enter the month index, 0 to 11 =  5

# %%
months=["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# %%
average_temp=[-3.5, -4.5, -1.0, 4.0, 10.0, 15.0, 18.0, 16.0, 11.5, 6.0, 2.0, -1.5]

# %%
len(months)
# Out:
# 12

# %%
len(average_temp)
# Out:
# 12

# %%
print(months[2])
# Out:
# March

# %%
print(average_temp[2])
# Out:
# -1.0

# %%
isinstance(months,list)
# Out:
# True

# %%
average_temp[int(selected_month_index)]
# Out:
# 15.0

# %%
print('The average temperatuer in Helsinki in', months[int(selected_month_index)], 'is', average_temp[int(selected_month_index)])
