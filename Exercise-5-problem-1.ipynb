# %%
import pandas as pd

# %%
data = pd.read_csv("6153237444115dat.csv", na_values=['*', '**', '***', '****', '*****', '******'])

# %%
data.head()
# Out:
#     USAF   WBAN  YR--MODAHRMN    DIR   SPD   GUS  CLG  SKC   L   M  ...  \
# 0  28450  99999  201705010000  174.0  10.0  14.0  NaN  NaN NaN NaN  ...
# 1  28450  99999  201705010020  180.0  10.0   NaN  4.0  NaN NaN NaN  ...
# 2  28450  99999  201705010050  190.0  10.0   NaN  4.0  NaN NaN NaN  ...
# 3  28450  99999  201705010100  188.0  12.0  16.0  NaN  NaN NaN NaN  ...
# 4  28450  99999  201705010120  200.0  13.0   NaN  2.0  OBS NaN NaN  ...
#
#       SLP    ALT    STP  MAX  MIN  PCP01  PCP06  PCP24  PCPXX    SD
# 0  1009.2    NaN  984.1  NaN  NaN    NaN    NaN    NaN    NaN  35.0
# 1     NaN  29.74    NaN  NaN  NaN    NaN    NaN    NaN    NaN   NaN
# 2     NaN  29.74    NaN  NaN  NaN    NaN    NaN    NaN    NaN   NaN
# 3  1009.1    NaN  984.0  NaN  NaN    NaN    NaN    NaN    NaN  35.0
# 4     NaN  29.74    NaN  NaN  NaN    NaN    NaN    NaN    NaN   NaN
#
# [5 rows x 33 columns]

# %%
row_count = len(data)

# %%
column_names = data.columns

# %%
column_datatypes = data.dtypes

# %%
print(f"There are {row_count} rows")
# Out:
# There are 11694 rows

# %%
print(f"The columns are: \n{column_names}")
# Out:
# The columns are:
# Index(['USAF', 'WBAN', 'YR--MODAHRMN', 'DIR', 'SPD', 'GUS', 'CLG', 'SKC', 'L',
#        'M', 'H', 'VSB', 'MW', 'MW.1', 'MW.2', 'MW.3', 'AW', 'AW.1', 'AW.2',
#        'AW.3', 'W', 'TEMP', 'DEWP', 'SLP', 'ALT', 'STP', 'MAX', 'MIN', 'PCP01',
#        'PCP06', 'PCP24', 'PCPXX', 'SD'],
#       dtype='object')

# %%
print(f"The column types are: \n{column_datatypes}")
# Out:
# The column types are:
# USAF              int64
# WBAN              int64
# YR--MODAHRMN      int64
# DIR             float64
# SPD             float64
# GUS             float64
# CLG             float64
# SKC              object
# L               float64
# M               float64
# H               float64
# VSB             float64
# MW              float64
# MW.1            float64
# MW.2            float64
# MW.3            float64
# AW              float64
# AW.1            float64
# AW.2            float64
# AW.3            float64
# W               float64
# TEMP            float64
# DEWP            float64
# SLP             float64
# ALT             float64
# STP             float64
# MAX             float64
# MIN             float64
# PCP01           float64
# PCP06           float64
# PCP24           float64
# PCPXX           float64
# SD              float64
# dtype: object

# %%
data["TEMP"].head()
# Out:
# 0    31.0
# 1    30.0
# 2    30.0
# 3    31.0
# 4    30.0
# Name: TEMP, dtype: float64

# %%
data.dropna(subset=["TEMP"])
# Out:
#         USAF   WBAN  YR--MODAHRMN    DIR   SPD   GUS   CLG  SKC   L   M  ...  \
# 0      28450  99999  201705010000  174.0  10.0  14.0   NaN  NaN NaN NaN  ...
# 1      28450  99999  201705010020  180.0  10.0   NaN   4.0  NaN NaN NaN  ...
# 2      28450  99999  201705010050  190.0  10.0   NaN   4.0  NaN NaN NaN  ...
# 3      28450  99999  201705010100  188.0  12.0  16.0   NaN  NaN NaN NaN  ...
# 4      28450  99999  201705010120  200.0  13.0   NaN   2.0  OBS NaN NaN  ...
# ...      ...    ...           ...    ...   ...   ...   ...  ...  ..  ..  ...
# 11689  29980  99999  201708311900  144.0  12.0  20.0  50.0  BKN NaN NaN  ...
# 11690  29980  99999  201708312000  137.0  14.0  20.0  40.0  BKN NaN NaN  ...
# 11691  29980  99999  201708312100  160.0  13.0   NaN   NaN  BKN NaN NaN  ...
# 11692  29980  99999  201708312200  170.0  12.0  21.0  28.0  OVC NaN NaN  ...
# 11693  29980  99999  201708312300  192.0  13.0  21.0  19.0  BKN NaN NaN  ...
#
# ...

# %%
temp_mean = data["TEMP"].mean().round(0)

# %%
data.dropna(subset=["MAX"])
# Out:
#         USAF   WBAN  YR--MODAHRMN    DIR   SPD   GUS    CLG  SKC   L   M  ...  \
# 18     28450  99999  201705010600  216.0  11.0  18.0    NaN  NaN NaN NaN  ...
# 54     28450  99999  201705011800  229.0  15.0  23.0    NaN  NaN NaN NaN  ...
# 90     28450  99999  201705020600  286.0  16.0  25.0  722.0  SCT NaN NaN  ...
# 126    28450  99999  201705021800  318.0  11.0  23.0    NaN  NaN NaN NaN  ...
# 161    28450  99999  201705030600  324.0   9.0  15.0    NaN  BKN NaN NaN  ...
# ...      ...    ...           ...    ...   ...   ...    ...  ...  ..  ..  ...
# 11640  29980  99999  201708291800  209.0  15.0  22.0   47.0  BKN NaN NaN  ...
# 11652  29980  99999  201708300600  198.0  16.0  26.0  722.0  SCT NaN NaN  ...
# 11664  29980  99999  201708301800  219.0  15.0  23.0    9.0  BKN NaN NaN  ...
# 11676  29980  99999  201708310600  158.0   8.0  12.0   10.0  BKN NaN NaN  ...
# 11688  29980  99999  201708311800  151.0  15.0  26.0   70.0  OVC NaN NaN  ...
#
# ...

# %%
temp_max_std = data["MAX"].std().round(0)

# %%
unique = data["USAF"].unique()

# %%
station_count = len (unique)

# %%
print(f"The mean temperature in Fahrenheit is {temp_mean}")
# Out:
# The mean temperature in Fahrenheit is 52.0

# %%
print(f"The standard deviation of maximum temperature is {temp_max_std}")
# Out:
# The standard deviation of maximum temperature is 10.0

# %%
print(f"The number of unique stations is {station_count}")
# Out:
# The number of unique stations is 2
