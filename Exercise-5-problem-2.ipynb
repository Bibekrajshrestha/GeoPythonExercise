# %%
import pandas as pd

# %%
data = pd.read_csv("6153237444115dat.csv")

# %%
data.head()
# Out:
#     USAF   WBAN  YR--MODAHRMN  DIR SPD  GUS  CLG  SKC  L  M  ...     SLP  \
# 0  28450  99999  201705010000  174  10   14  ***  ***  *  *  ...  1009.2
# 1  28450  99999  201705010020  180  10  ***    4  ***  *  *  ...  ******
# 2  28450  99999  201705010050  190  10  ***    4  ***  *  *  ...  ******
# 3  28450  99999  201705010100  188  12   16  ***  ***  *  *  ...  1009.1
# 4  28450  99999  201705010120  200  13  ***    2  OBS  *  *  ...  ******
#
#      ALT     STP  MAX  MIN  PCP01  PCP06  PCP24  PCPXX  SD
# 0  *****   984.1  ***  ***  *****  *****  *****  *****  35
# 1  29.74  ******  ***  ***  *****  *****  *****  *****  **
# 2  29.74  ******  ***  ***  *****  *****  *****  *****  **
# 3  *****   984.0  ***  ***  *****  *****  *****  *****  35
# 4  29.74  ******  ***  ***  *****  *****  *****  *****  **
#
# [5 rows x 33 columns]

# %%
len(data)
# Out:
# 11694

# %%
selected = data.loc[:,["USAF", "YR--MODAHRMN", "TEMP", "MAX", "MIN"]]
selected
# Out:
#         USAF  YR--MODAHRMN TEMP  MAX  MIN
# 0      28450  201705010000   31  ***  ***
# 1      28450  201705010020   30  ***  ***
# 2      28450  201705010050   30  ***  ***
# 3      28450  201705010100   31  ***  ***
# 4      28450  201705010120   30  ***  ***
# ...      ...           ...  ...  ...  ...
# 11689  29980  201708311900   64  ***  ***
# 11690  29980  201708312000   64  ***  ***
# 11691  29980  201708312100   64  ***  ***
# 11692  29980  201708312200   64  ***  ***
# 11693  29980  201708312300   64  ***  ***
#
# [11694 rows x 5 columns]

# %%
selected = selected.dropna(subset=["TEMP"])
selected
# Out:
#         USAF  YR--MODAHRMN TEMP  MAX  MIN  Celsius
# 0      28450  201705010000   31  ***  ***      0.0
# 1      28450  201705010020   30  ***  ***      0.0
# 2      28450  201705010050   30  ***  ***      0.0
# 3      28450  201705010100   31  ***  ***      0.0
# 4      28450  201705010120   30  ***  ***      0.0
# ...      ...           ...  ...  ...  ...      ...
# 11689  29980  201708311900   64  ***  ***      0.0
# 11690  29980  201708312000   64  ***  ***      0.0
# 11691  29980  201708312100   64  ***  ***      0.0
# 11692  29980  201708312200   64  ***  ***      0.0
# 11693  29980  201708312300   64  ***  ***      0.0
#
# [11694 rows x 6 columns]

# %%
selected ["Celsius"] = (selected["TEMP"] - 32)/1.8
selected
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/computation/expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# ...

# %%
selected.head()
# Out:
#     USAF  YR--MODAHRMN TEMP  MAX  MIN  Celsius
# 0  28450  201705010000   31  ***  ***      0.0
# 1  28450  201705010020   30  ***  ***      0.0
# 2  28450  201705010050   30  ***  ***      0.0
# 3  28450  201705010100   31  ***  ***      0.0
# 4  28450  201705010120   30  ***  ***      0.0

# %%
kumpula = selected.loc[selected["USAF"] == 29980]

# %%
kumpula
# Out:
#         USAF  YR--MODAHRMN TEMP  MAX  MIN  Celsius
# 8770   29980  201705010000   37  ***  ***      0.0
# 8771   29980  201705010100   37  ***  ***      0.0
# 8772   29980  201705010200   37  ***  ***      0.0
# 8773   29980  201705010300   37  ***  ***      0.0
# 8774   29980  201705010400   39  ***  ***      0.0
# ...      ...           ...  ...  ...  ...      ...
# 11689  29980  201708311900   64  ***  ***      0.0
# 11690  29980  201708312000   64  ***  ***      0.0
# 11691  29980  201708312100   64  ***  ***      0.0
# 11692  29980  201708312200   64  ***  ***      0.0
# 11693  29980  201708312300   64  ***  ***      0.0
#
# [2924 rows x 6 columns]

# %%
rovavniemi = selected.loc[selected["USAF"]==28450]

# %%
rovavniemi
# Out:
#        USAF  YR--MODAHRMN TEMP  MAX  MIN  Celsius
# 0     28450  201705010000   31  ***  ***      0.0
# 1     28450  201705010020   30  ***  ***      0.0
# 2     28450  201705010050   30  ***  ***      0.0
# 3     28450  201705010100   31  ***  ***      0.0
# 4     28450  201705010120   30  ***  ***      0.0
# ...     ...           ...  ...  ...  ...      ...
# 8765  28450  201708312220   46  ***  ***      0.0
# 8766  28450  201708312250   46  ***  ***      0.0
# 8767  28450  201708312300   48  ***  ***      0.0
# 8768  28450  201708312320   46  ***  ***      0.0
# 8769  28450  201708312350   48  ***  ***      0.0
#
# [8770 rows x 6 columns]

# %%
print(f"Kumpula: \n{kumpula.head()}\n")
# Out:
# Kumpula:
#        USAF  YR--MODAHRMN TEMP  MAX  MIN  Celsius
# 8770  29980  201705010000   37  ***  ***      0.0
# 8771  29980  201705010100   37  ***  ***      0.0
# 8772  29980  201705010200   37  ***  ***      0.0
# 8773  29980  201705010300   37  ***  ***      0.0
# 8774  29980  201705010400   39  ***  ***      0.0

# %%
print(f"Rovaniemi: \n{rovavniemi.head()}\n")
# Out:
# Rovaniemi:
#     USAF  YR--MODAHRMN TEMP  MAX  MIN  Celsius
# 0  28450  201705010000   31  ***  ***      0.0
# 1  28450  201705010020   30  ***  ***      0.0
# 2  28450  201705010050   30  ***  ***      0.0
# 3  28450  201705010100   31  ***  ***      0.0
# 4  28450  201705010120   30  ***  ***      0.0

# %%
output_fp="Kumpula_temps_May_Aug_2017.csv"
data.to_csv(output_fp, sep=",", float_format = "%.2f")

# %%
output_fp2="Rovaniemi_temps_May_Aug_2017.csv"
data.to_csv(output_fp2,sep=",", float_format = "%.2f")
