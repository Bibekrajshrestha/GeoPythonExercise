# %%
#Ex2-problem 2
selected_month_index = input('enter the month index, 0 to 11 = ')
# Out:
# enter the month index, 0 to 11 =  5

# %%
months=["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

# %%
average_temp=[-3.5, -4.5, -1.0, 4.0, 10.0, 15.0, 18.0, 16.0, 11.5, 6.0, 2.0, -1.5]

# %%
print('The average temperature in Helsinki in', months[int(selected_month_index)], 'is', average_temp[int(selected_month_index)])
# Out:
# The average temperature in Helsinki in June is 15.0
