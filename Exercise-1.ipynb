# %%
ice_cream_rating = input("How much do you enjoy ice cream, rate between 0 to 10? ")
# Out:
# How much do you enjoy ice cream, rate between 0 to 10?  7

# %%
sleep_rating = input("How much do you enjoy sleeping, rate between 0 to 10? ")
# Out:
# How much do you enjoy sleeping, rate between 0 to 10?  9

# %%
first_name = input("your first name?")
# Out:
# your first name? Bibek

# %%
last_name = input("your last name?")
# Out:
# your last name? Shrestha

# %%
my_name = first_name + last_name

# %%
happiness_rating = (int(ice_cream_rating) + int(sleep_rating)) / 2

# %%
type(ice_cream_rating)
# Out:
# str

# %%
type(first_name)
# Out:
# str

# %%
type(happiness_rating)
# Out:
# float

# %%
print(happiness_rating)
# Out:
# 8.0

# %%
print ("My name is", first_name + "and I give eating eating ice cream a score of", ice_cream_rating, "out of 10! I am", my_name, "and my sleeping enjoyment rating is", sleep_rating, "/ 10! Based on the factor above, my happines rating is", happiness_rating, "out of 10, or", happiness_rating*10, "%!")
# Out:
# My name is Bibek and I give eating eating ice cream a score of 7 out of 10! I am Bibek Shrestha and my sleeping enjoyment rating is 9 / 10! Based on the factor above, my happines rating is 8.0 out of 10, or 80.0 %!
